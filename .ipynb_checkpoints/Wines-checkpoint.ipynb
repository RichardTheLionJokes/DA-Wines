# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy as sp
import glob

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from plotnine import ggplot, aes, geom_point, geom_histogram, geom_segment, xlim

# %%
# Часть 1

# %%
# 1.1

# %%
names = glob.glob(r'data/*.csv')
wine_data = pd.concat([pd.read_csv(path, sep=';', decimal=',') for path in names])

# %%
wine_data.shape
# Out:
# (149908, 12)

# %%
# 1.2

# %%
repl_dict = {'а':'a','А':'A','о':'o','О':'O','е':'e','Е':'E'}
for key, value in repl_dict.items():
    wine_data['taster_name'] = wine_data['taster_name'].str.replace(key, value)

# %%
wine_data.drop_duplicates(inplace=True)
wine_data.shape
# Out:
# (119929, 12)

# %%
wine_data['taster_name'].nunique(dropna = False)
# Out:
# 20

# %%
# 1.3, 1.4

# %%
wine_data = wine_data.fillna({'price': wine_data['price'].median()})

# %%
display(wine_data['points'].mean())
display(wine_data['points'].median())
display(wine_data['points'].std())
# Out:
# 88.44214493575366
# 88.0
# 3.093274618268554

# %%
display(wine_data['price'].mean())
display(wine_data['price'].median())
display(wine_data['price'].std())
# Out:
# 34.88263889467935
# 25.0
# 40.703298162136534

# %%
ggplot(wine_data) + aes(x='points') + geom_histogram(binwidth=1, fill='blue')
# Out:
# <ggplot: (-9223371942365233528)>

# %%
ggplot(wine_data) + aes(x='price') + geom_histogram(binwidth=10, fill='blue') + xlim(0,300)
# Out:
# C:\Users\Richard\AppData\Roaming\Python\Python37\site-packages\plotnine\layer.py:324: PlotnineWarning: stat_bin : Removed 312 rows containing non-finite values.
# C:\Users\Richard\AppData\Roaming\Python\Python37\site-packages\plotnine\layer.py:401: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
# <ggplot: (-9223371942276584176)>

# %%
# Распределение price имеет явную ассиметрию, имеются выбросы. Поэтому используем коэффициент корреляции Спирмена.
# Видим, что между переменными имеется слабаяположительная связь
sp.stats.spearmanr(wine_data['points'], wine_data['price'])
# Out:
# SpearmanrResult(correlation=0.5875133270165194, pvalue=0.0)

# %%
# Покажем связь переменных на графике
ggplot(wine_data) + aes(x='price', y='points') + xlim(0,300) + geom_point(alpha=0.02, color='blue')
# Out:
# C:\Users\Richard\AppData\Roaming\Python\Python37\site-packages\plotnine\layer.py:401: PlotnineWarning: geom_point : Removed 312 rows containing missing values.
# <ggplot: (-9223371942365080116)>

# %%
# Для более наглядного отражения связи переменных, произведем небольшие преобразования данных
wine_data['price_log'] = wine_data['price'].apply(np.log)
wine_data['points_noise'] = wine_data['points'].apply(lambda x: np.random.uniform(-0.5, 0.5) + x)

# %%
ggplot(wine_data) + aes(x='price_log', y='points_noise') + labs(y="points") + geom_point(alpha=0.02, color='blue')
# Out:
# <ggplot: (-9223371942244358264)>

# %%
# Часть 2

# %%
wine_data.head()
# Out:
#    entry_id    country                                        description  \
# 0    119966  Argentina  Raspberry and cassis aromas are fresh and upri...
# 1    119956  Argentina  Compared to the regular 2006 Malbec from Chaka...
# 2    119950  Argentina  Andeluna's top wines tend to be ripe and plump...
# 3    119943  Argentina  A lively, well-made blend of Tempranillo, Malb...
# 4    119939  Argentina  There is a select group of under-$20 Malbecs f...
#
#           designation  points  price          province         region  \
# 0            Pedernal      90   43.0             Other       San Juan
# 1             Reserve      91   25.0  Mendoza Province  Luján de Cuyo
# 2           Pasionado      91   55.0  Mendoza Province     Uco Valley
# 3              B Crux      91   24.0  Mendoza Province     Uco Valley
# 4  La Madras Vineyard      91   18.0  Mendoza Province        Mendoza
#
#          taster_name                                              title  \
# 0  Michael Schachner    Finca Las Moras 2010 Pedernal Malbec (San Juan)
# 1  Michael Schachner        Chakana 2006 Reserve Malbec (Luján de Cuyo)
# 2  Michael Schachner           Andeluna 2004 Pasionado Red (Uco Valley)
# 3  Michael Schachner           O. Fournier 2005 B Crux Red (Uco Valley)
# 4  Michael Schachner  Ricardo Santos 2006 La Madras Vineyard Malbec ...
#
#      variety           winery  price_log  points_noise
# 0     Malbec  Finca Las Moras   3.761200     89.652794
# 1     Malbec          Chakana   3.218876     91.080916
# 2  Red Blend         Andeluna   4.007333     91.400749
# 3  Red Blend      O. Fournier   3.178054     90.513719
# 4     Malbec   Ricardo Santos   2.890372     90.966036

# %%
# 2.1

# %%
top5_df = wine_data.groupby(['taster_name'], as_index=False).aggregate({'entry_id': 'count'})\
.rename(columns={'entry_id' : 'count'}).sort_values(['count'], ascending=False).head()

# %%
# Топ-5самых продуктивных авторов
top5_df.head(5)
# Out:
#           taster_name  count
# 15         Roger Voss  23558
# 12  Michael Schachner  14039
# 9       Kerin O’Keefe   9697
# 14       Paul Gregutt   8867
# 18     Virginie Boone   8708

# %%
# 2.2

# %%
top5_df_countries1 = top5_df.merge(wine_data, on=['taster_name'], how='left').groupby(['taster_name','country'], as_index=True)\
.size().to_frame('count').query('count > 1').sort_values(['taster_name', 'count'], ascending=[True, False])

# %%
# Выводим данные о странах и количестве отзывов по этим странам авторов из Топ-5 в виде таблицы
top5_df_countries1
# Out:
#                                 count
# taster_name       country
# Kerin O’Keefe     Italy          9697
# Michael Schachner Spain          6046
#                   Chile          4049
#                   Argentina      3542
#                   Uruguay          98
#                   Italy            76
#                   US               71
#                   Mexico           63
#                   Brazil           49
#                   France           20
#                   Peru             16
#                   Portugal          9
# Paul Gregutt      US             8666
#                   Canada          159
#                   France           34
#                   Italy             4
#                   Spain             4
# Roger Voss        France        17150
#                   Portugal       5223
#                   Austria        1064
#                   Italy            96
#                   South Africa     22
#                   US                2
# Virginie Boone    US             8708

# %%
top5_df_countries = top5_df.merge(wine_data, on=['taster_name'], how='left').groupby(['taster_name','country'], as_index=False)\
.size().query('size > 1').sort_values(['taster_name', 'size'], ascending=[True, False]).reset_index().drop(['index'], axis=1)

# %%
# Выводим данные о странах и количестве отзывов по этим странам авторов из Топ-5 в виде круговой диаграммы
def draw_pie(cur_taster, labels, vals):
    fig, ax = plt.subplots()
    ax.set_title(cur_taster)
    ax.pie(vals)
    ax.axis('equal')
    labels2 = [f"{l} ({v})" for l,v in zip(labels, vals)]
    ax.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0), labels=labels2)
    
cur_taster = top5_df_countries.iloc[0]['taster_name']
vals = []
labels = []
for i in range(len(top5_df_countries)):
    if (top5_df_countries.iloc[i]['taster_name'] != cur_taster) | (i == len(top5_df_countries)-1):
        df = pd.DataFrame({'count': vals, 'country': labels})
        draw_pie(cur_taster, labels, vals)
        vals.clear()
        labels.clear()
        cur_taster = top5_df_countries.iloc[i]['taster_name']
    labels.append(top5_df_countries.iloc[i]['country'])
    vals.append(top5_df_countries.iloc[i]['size'])
draw_pie(cur_taster, labels, vals)

# %%
# 2.3

# %%
top5_df_prices = top5_df.merge(wine_data, on=['taster_name'], how='inner')[['taster_name', 'price']]

# %%
# Если нужно проанализировать не только диапазон но и то, на каком участке диапазона было больше или меньше отзывов,
# строим точечную диаграмму
ggplot(top5_df_prices) + aes(x='price', y='taster_name', color='taster_name') + geom_point(alpha=0.5)
# Out:
# <ggplot: (-9223371942275481236)>

# %%
# Если нужно проанализировать только сам диапазон, можно построить диаграмму Ганта
top5_df_min_max = top5_df_prices.copy()
top5_df_min_max['price_min'] = top5_df_min_max['price']
top5_df_min_max['price_max'] = top5_df_min_max['price']
top5_df_min_max = top5_df_min_max.groupby(['taster_name'], as_index=False).aggregate({'price_min': 'min', 'price_max': 'max'})

# %%
ggplot(top5_df_min_max, aes(x='price_min', xend='price_max', y='taster_name', yend='taster_name', color='taster_name')) + geom_segment(size=8)
# Out:
# <ggplot: (-9223371942275174372)>

# %%
# Дополнительно

# %%
# Мы уже увидели, что имеется некоторая связь между оценкой и ценой. Посмотрим, что ещё может влиять на рейтинг.
# Можно предположить, что рейтинг зависит от сорта вина или от страны, в которой производится вино.

# %%
# Анализируя данные, видим, что связь между сортом вина и рейтингом действительно имеется.
wine_data.groupby(['variety'], as_index=False).aggregate({'points': 'mean', 'entry_id': 'count'})\
.rename(columns={'points' : 'mean', 'entry_id': 'count'}).query('count > 10').sort_values(['mean'], ascending=False)
# Out:
#                    variety       mean  count
# 419                Picolit  91.153846     26
# 578  Tannat-Cabernet Franc  90.928571     14
# 615                 Tokaji  90.750000     24
# 577        Tannat-Cabernet  90.571429     28
# 505      Sangiovese Grosso  90.563218    696
# ..                     ...        ...    ...
# 205         Garnacha-Syrah  84.500000     12
# 531           Seyval Blanc  84.200000     15
# 391                 Norton  84.000000     16
# 66               Brachetto  83.714286     14
# 120            Chambourcin  83.588235     17
#
# [276 rows x 3 columns]

# %%
# В то же время, анализируя следующий график для сортов вин со средним рейтингом выше 90, видим, что разброс достаточно большой,
# т.е. на основании лишь сорта нельзя однозначно сказать, что оценка будет высокой.
varieties = wine_data.groupby(['variety'], as_index=False).aggregate({'points': 'mean', 'entry_id': 'count'})\
.rename(columns={'points' : 'mean', 'entry_id': 'count'}).query('count > 10 & mean >= 90').sort_values(['mean'], ascending=False)
varieties = varieties.merge(wine_data, on=['variety'], how='inner')[['variety', 'points']]
ggplot(varieties) + aes(x='points', y='variety', color='variety') + geom_point(alpha=0.5)
# Out:
# <ggplot: (-9223371942254994888)>

# %%
# Так же видим, что имеется связь между рейтингом и страной происхождения вина.
wine_data.groupby(['country'], as_index=False).aggregate({'points': 'mean', 'entry_id': 'count'})\
.rename(columns={'points' : 'mean', 'entry_id': 'count'}).sort_values(['mean'], ascending=False)
# Out:
#                    country       mean  count
# 14                 England  91.746032     63
# 20                   India  90.250000      8
# 3                  Austria  90.129532   3034
# 17                 Germany  89.895582   1992
# 7                   Canada  89.309735    226
# 19                 Hungary  89.294574    129
# 9                    China  89.000000      1
# 15                  France  88.866752  20353
# 24              Luxembourg  88.800000      5
# 28                 Morocco  88.708333     24
# 22                   Italy  88.576198  17940
# 2                Australia  88.561220   2197
# 40                      US  88.555384  50457
# 38             Switzerland  88.500000      6
# 21                  Israel  88.454936    466
# 29             New Zealand  88.299687   1278
# 31                Portugal  88.263128   5256
# 35                Slovenia  88.129870     77
# 39                  Turkey  88.074074     81
# 36            South Africa  88.033820   1301
# 6                 Bulgaria  87.878788    132
# 33                  Serbia  87.625000      8
# 16                 Georgia  87.605263     76
# 23                 Lebanon  87.593750     32
# 1                  Armenia  87.500000      2
# 18                  Greece  87.238426    432
# 37                   Spain  87.235612   6116
# 10                 Croatia  87.185714     70
# 27                 Moldova  87.142857     56
# 11                  Cyprus  87.100000     10
# 12          Czech Republic  87.090909     11
# 34                Slovakia  87.000000      1
# 25               Macedonia  86.818182     11
# 42                 Uruguay  86.663265     98
# 0                Argentina  86.649831   3544
# 4   Bosnia and Herzegovina  86.500000      2
# 8                    Chile  86.460564   4184
# 32                 Romania  86.313725    102
# 26                  Mexico  85.161765     68
# 5                   Brazil  84.632653     49
# 41                 Ukraine  84.071429     14
# 13                   Egypt  84.000000      1
# 30                    Peru  83.562500     16

# %%
# Проанализировав следующий график, видим, что, например, английское вино стабильно получает высокие оценки,
# в то время как, например, вина из Румынии, Мексики и Бразилии как правило имеют рейтинг ниже 90.
# Но в то же время рейтинг, например, американских и португальских вин имеет довольно сильный разброс,
# и сложно по одной лишь стране предсказать рейтинг.
ggplot(wine_data) + aes(x='points', y='country', color='country') + geom_point(alpha=0.5)
# Out:
# <ggplot: (-9223371942273065296)>

# %%
wine_data = wine_data.fillna({'region': 'Not'})
wine_data = wine_data.fillna({'designation': 'Not'})
wine_data = wine_data.fillna({'variety': 'Not'})

# %%
# Если нужно получить более явную связь, то стоит сузить поиск до провинции, региона или, лучше всего, до винодельни:
wine_data.groupby(['winery'], as_index=False).aggregate({'points': 'mean', 'entry_id': 'count'})\
.rename(columns={'points' : 'mean', 'entry_id': 'count'}).query('count > 10 & mean >= 90').sort_values(['mean'], ascending=False)
# Out:
#                      winery       mean  count
# 16320              Wayfarer  95.333333     18
# 8589             Horsepower  95.090909     11
# 3928   Château Pontet-Canet  95.000000     13
# 7765                   Gaja  94.894737     19
# 3461     Château Haut-Brion  94.700000     20
# ...                     ...        ...    ...
# 3094          Château Brown  90.000000     15
# 1218   Besserat de Bellefon  90.000000     19
# 5048        Conceito Vinhos  90.000000     20
# 4864            Clos Solène  90.000000     12
# 6433      Domaine du Castel  90.000000     12
#
# [869 rows x 3 columns]

# %%
# Здесь, например, видим, что у винодельни с лучшим средним рейтингом оценка вообще не опускается ниже 93.
wine_data.query('winery == "Wayfarer"').sort_values(['points'], ascending=False)
# Out:
#        entry_id country                                        description  \
# 60697      4488      US  Structured, with years to go to take on added ...
# 34508     55036      US  This is yet another stunning wine from this si...
# 38974     46598      US  From an estate block planted to a mysterious s...
# 60695      4491      US  Dark, brooding cinnamon and fleshy black plum ...
# 60692      4493      US  Youthfully flippant, this block of the Wayfare...
# 60690      4495      US  Floral in aromas and yet darkly savory in cher...
# 38969     46602      US  Crafted from estate-grown fruit—a marriage of ...
# 18314     85985      US  This marks another stellar vintage of The Trav...
# 36414     51331      US  A high-acid, weighty and complex white, this v...
# 38962     46610      US  Brooding in dark cherry and earthy spice, this...
# 16344     89690      US  Lush and velvety, this wine offers big, dark c...
# 60679      4506      US  Crafted from 12 different clones planted throu...
# 36409     51338      US  From a section of the vineyard planted to only...
# 54968     15435      US  Estate grown, this is the only white from the ...
# 36404     51345      US  This wine blends all 12 clones of Pinot Noir g...
# 21314     80151      US  An estate blend of 12 different clones, this d...
# 51213     22921      US  From one block of the estate vineyard planted ...
# 5934     108973      US  A brooding, savory and smoothly textured wine,...
#
#                           designation  points  price    province  \
# 60697                    The Traveler      98  155.0  California
# 34508               Wayfarer Vineyard      98   80.0  California
# 38974                    The Traveler      97  150.0  California
# 60695                     Golden Mean      97  115.0  California
# 60692                     Mother Rock      96  115.0  California
# 60690                   Paige's Ridge      96  115.0  California
# 38969                     Golden Mean      96  115.0  California
# 18314       Estate Grown The Traveler      96  150.0  California
# 36414               Wayfarer Vineyard      95   80.0  California
# 38962                     Mother Rock      95  115.0  California
# 16344        Estate Grown Golden Mean      95  115.0  California
# 60679               Wayfarer Vineyard      95   90.0  California
# 36409      Paige's Ridge Estate Grown      94  115.0  California
# 54968               Wayfarer Vineyard      94   80.0  California
# 36404  Wayfarer Vineyard Estate Grown      94   90.0  California
# 21314               Wayfarer Vineyard      94   90.0  California
# 51213                   Paige's Ridge      93  125.0  California
# 5934         Estate Grown Mother Rock      93  115.0  California
#
#                   region     taster_name  \
# 60697  Fort Ross-Seaview  Virginie Boone
# 34508  Fort Ross-Seaview  Virginie Boone
# 38974  Fort Ross-Seaview  Virginie Boone
# 60695  Fort Ross-Seaview  Virginie Boone
# 60692  Fort Ross-Seaview  Virginie Boone
# 60690  Fort Ross-Seaview  Virginie Boone
# 38969  Fort Ross-Seaview  Virginie Boone
# 18314  Fort Ross-Seaview  Virginie Boone
# 36414  Fort Ross-Seaview  Virginie Boone
# 38962  Fort Ross-Seaview  Virginie Boone
# 16344  Fort Ross-Seaview  Virginie Boone
# 60679  Fort Ross-Seaview  Virginie Boone
# 36409  Fort Ross-Seaview  Virginie Boone
# 54968  Fort Ross-Seaview  Virginie Boone
# 36404  Fort Ross-Seaview  Virginie Boone
# 21314  Fort Ross-Seaview  Virginie Boone
# 51213  Fort Ross-Seaview  Virginie Boone
# 5934   Fort Ross-Seaview  Virginie Boone
#
#                                                    title     variety  \
# 60697  Wayfarer 2014 The Traveler Pinot Noir (Fort Ro...  Pinot Noir
# 34508  Wayfarer 2014 Wayfarer Vineyard Chardonnay (Fo...  Chardonnay
# 38974  Wayfarer 2012 The Traveler Pinot Noir (Fort Ro...  Pinot Noir
# 60695  Wayfarer 2014 Golden Mean Pinot Noir (Fort Ros...  Pinot Noir
# 60692  Wayfarer 2014 Mother Rock Pinot Noir (Fort Ros...  Pinot Noir
# 60690  Wayfarer 2014 Paige's Ridge Pinot Noir (Fort R...  Pinot Noir
# 38969  Wayfarer 2012 Golden Mean Pinot Noir (Fort Ros...  Pinot Noir
# 18314  Wayfarer 2013 Estate Grown The Traveler Pinot ...  Pinot Noir
# 36414  Wayfarer 2013 Wayfarer Vineyard Chardonnay (Fo...  Chardonnay
# 38962  Wayfarer 2012 Mother Rock Pinot Noir (Fort Ros...  Pinot Noir
# 16344  Wayfarer 2013 Estate Grown Golden Mean Pinot N...  Pinot Noir
# 60679  Wayfarer 2014 Wayfarer Vineyard Pinot Noir (Fo...  Pinot Noir
# 36409  Wayfarer 2013 Paige's Ridge Estate Grown Pinot...  Pinot Noir
# 54968  Wayfarer 2012 Wayfarer Vineyard Chardonnay (Fo...  Chardonnay
# 36404  Wayfarer 2013 Wayfarer Vineyard Estate Grown P...  Pinot Noir
# 21314  Wayfarer 2012 Wayfarer Vineyard Pinot Noir (Fo...  Pinot Noir
# 51213  Wayfarer 2012 Paige's Ridge Pinot Noir (Fort R...  Pinot Noir
# 5934   Wayfarer 2013 Estate Grown Mother Rock Pinot N...  Pinot Noir
#
#          winery  price_log  points_noise
# 60697  Wayfarer   5.043425     97.770275
# 34508  Wayfarer   4.382027     98.181138
# 38974  Wayfarer   5.010635     97.484955
# 60695  Wayfarer   4.744932     97.436210
# 60692  Wayfarer   4.744932     96.221938
# 60690  Wayfarer   4.744932     95.539605
# 38969  Wayfarer   4.744932     95.641718
# 18314  Wayfarer   5.010635     95.526280
# 36414  Wayfarer   4.382027     95.124341
# 38962  Wayfarer   4.744932     95.299061
# 16344  Wayfarer   4.744932     94.918585
# 60679  Wayfarer   4.499810     94.953239
# 36409  Wayfarer   4.744932     94.182204
# 54968  Wayfarer   4.382027     94.061830
# 36404  Wayfarer   4.499810     93.786938
# 21314  Wayfarer   4.499810     94.450110
# 51213  Wayfarer   4.828314     93.101394
# 5934   Wayfarer   4.744932     93.162415
